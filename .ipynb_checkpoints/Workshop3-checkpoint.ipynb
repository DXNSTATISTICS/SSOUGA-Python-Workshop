# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Line Graph

# %%
years = [1950,1960,1970,1980,1990,2000]
dollars = [300,400,555,222,492,600]

# %%
plt.plot(years, dollars, color = 'red', marker='o', linestyle='solid')

# %%
plt.plot(years, dollars, color = 'red', marker='o', linestyle='solid')
plt.title("Random Graph I Invented")
plt.ylabel("Dollars in Dollars")
plt.xlabel("Year")
plt.show()

# %% [markdown]
# # Bar Charts

# %%
Names = ["Tom Brady", "Aaron Rodgers", "Matt Ryan", "Bryan Dixon", "Russell Wilson"]
SuperBowlWins = [7,1,0,0,1]
SuperBowlAppearances = [10,1,1,0,2]

# %%
plt.bar(Names,SuperBowlWins)
plt.title("Super Bowl Wins")
plt.ylabel("Wins")
plt.show()

#plt.savefig('superbwolwins.png')

# %%
import numpy as np

Names = ["Tom Brady", "Aaron Rodgers", "Matt Ryan", "Bryan Dixon", "Russell Wilson"]
SuperBowlWins = [7,1,0,0,1]
SuperBowlAppearances = [10,1,1,0,2]

X_axis = np.arange(len(Names))
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(X_axis - width/2, SuperBowlWins, width, label='SB Wins')
rects2 = ax.bar(X_axis + width/2, SuperBowlAppearances, width, label='SB Appearances')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Count')
ax.set_title('Wins VS Appearances')
ax.set_xticks(X_axis,Names,rotation = 45)
ax.legend()

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)

fig.tight_layout()
#plt.rcParams["figure.figsize"] = (5,5)

plt.show()
